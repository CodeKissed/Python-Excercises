# %% [markdown]
# ### PRACTICE DATA WRANGLING

# %% [markdown]
# This notebook shows some common data wrangling techniques. The dataset used contains the prices and other attributes of almost 54,000 diamonds. The dataset can be accesed through this link: https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv.
#
# Below is a  Pandas practice set found in https://www.w3resource.com/python-exercises/pandas/practice-set1/index.php which I find very useful for beginners to be familiar with the most common functions and methods in processing data. Most Python online courses do not usually cover all techniques shared in this practice data set.

# %%
import pandas as pd

# %%
diamonds = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv')
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
# Modify the default columns values and print the first 6 rows.

df = diamonds.loc[:,["carat", "cut", "x", "y", "z"]]
df.columns = df.columns.str.capitalize()
df.head(6)
# Out:
#    Carat        Cut     X     Y     Z
# 0   0.23      Ideal  3.95  3.98  2.43
# 1   0.21    Premium  3.89  3.84  2.31
# 2   0.23       Good  4.05  4.07  2.31
# 3   0.29    Premium  4.20  4.23  2.63
# 4   0.31       Good  4.34  4.35  2.75
# 5   0.24  Very Good  3.94  3.96  2.48

# %%
# Select a series from diamonds DataFrame.
diamonds["carat"]
# Out:
# 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 53940, dtype: float64

# %%
# Add a new column labeled 'Quality -color'
diamonds["quality - color"] = diamonds.cut + ' , ' + diamonds.color
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#   quality - color
# 0       Ideal , E
# 1     Premium , E
# 2        Good , E
# 3     Premium , I
# 4        Good , J

# %%
# Find the number of rows and columns and data type of each column of diamonds Dataframe.
diamonds.shape
# Out:
# (53940, 11)

# %%
diamonds.dtypes
# Out:
# carat              float64
# cut                 object
# color               object
# clarity             object
# depth              float64
# table              float64
# price                int64
# x                  float64
# y                  float64
# z                  float64
# quality - color     object
# dtype: object

# %%
# Summarize only 'object' columns of the diamonds Dataframe.
diamonds.describe(include =['object'])
# Out:
#           cut  color clarity quality - color
# count   53940  53940   53940           53940
# unique      5      7       8              35
# top     Ideal      G     SI1       Ideal , G
# freq    21551  11292   13065            4884

# %%
# Rename two of the columns of the df Dataframe
df.rename(columns={"Cut": "Diamond_Cut", "Carat": "Diamond_Carat"})
# Out:
#        Diamond_Carat Diamond_Cut     X     Y     Z
# 0               0.23       Ideal  3.95  3.98  2.43
# 1               0.21     Premium  3.89  3.84  2.31
# 2               0.23        Good  4.05  4.07  2.31
# 3               0.29     Premium  4.20  4.23  2.63
# 4               0.31        Good  4.34  4.35  2.75
# ...              ...         ...   ...   ...   ...
# 53935           0.72       Ideal  5.75  5.76  3.50
# 53936           0.72        Good  5.69  5.75  3.61
# 53937           0.70   Very Good  5.66  5.68  3.56
# 53938           0.86     Premium  6.15  6.12  3.74
# 53939           0.75       Ideal  5.83  5.87  3.64
#
# [53940 rows x 5 columns]

# %%
# Rename all the columns of the df Dataframe.
# Option 1

cols = ["Diamond_Carat", "Diamond_Cut", "Diamond_X", "Diamond_Y", "Diamond_Z"]
df.set_axis([cols], axis=1)
# Out:
#       Diamond_Carat Diamond_Cut Diamond_X Diamond_Y Diamond_Z
# 0              0.23       Ideal      3.95      3.98      2.43
# 1              0.21     Premium      3.89      3.84      2.31
# 2              0.23        Good      4.05      4.07      2.31
# 3              0.29     Premium      4.20      4.23      2.63
# 4              0.31        Good      4.34      4.35      2.75
# ...             ...         ...       ...       ...       ...
# 53935          0.72       Ideal      5.75      5.76      3.50
# 53936          0.72        Good      5.69      5.75      3.61
# 53937          0.70   Very Good      5.66      5.68      3.56
# 53938          0.86     Premium      6.15      6.12      3.74
# 53939          0.75       Ideal      5.83      5.87      3.64
#
# [53940 rows x 5 columns]

# %%
# Option 2
cols = ["Diamond_Carat", "Diamond_Cut", "Diamond_X", "Diamond_Y", "Diamond_Z"]
df.columns = cols
df
# Out:
#        Diamond_Carat Diamond_Cut  Diamond_X  Diamond_Y  Diamond_Z
# 0               0.23       Ideal       3.95       3.98       2.43
# 1               0.21     Premium       3.89       3.84       2.31
# 2               0.23        Good       4.05       4.07       2.31
# 3               0.29     Premium       4.20       4.23       2.63
# 4               0.31        Good       4.34       4.35       2.75
# ...              ...         ...        ...        ...        ...
# 53935           0.72       Ideal       5.75       5.76       3.50
# 53936           0.72        Good       5.69       5.75       3.61
# 53937           0.70   Very Good       5.66       5.68       3.56
# 53938           0.86     Premium       6.15       6.12       3.74
# 53939           0.75       Ideal       5.83       5.87       3.64
#
# [53940 rows x 5 columns]

# %%
#Remove the second column of the df Dataframe
df.drop(["Diamond_Cut"], axis =1)
# Out:
#        Diamond_Carat  Diamond_X  Diamond_Y  Diamond_Z
# 0               0.23       3.95       3.98       2.43
# 1               0.21       3.89       3.84       2.31
# 2               0.23       4.05       4.07       2.31
# 3               0.29       4.20       4.23       2.63
# 4               0.31       4.34       4.35       2.75
# ...              ...        ...        ...        ...
# 53935           0.72       5.75       5.76       3.50
# 53936           0.72       5.69       5.75       3.61
# 53937           0.70       5.66       5.68       3.56
# 53938           0.86       6.15       6.12       3.74
# 53939           0.75       5.83       5.87       3.64
#
# [53940 rows x 4 columns]

# %%
#Remove the multiple columns of the df Dataframe
df.drop(["Diamond_Cut", "Diamond_Carat"], axis =1)
# Out:
#        Diamond_X  Diamond_Y  Diamond_Z
# 0           3.95       3.98       2.43
# 1           3.89       3.84       2.31
# 2           4.05       4.07       2.31
# 3           4.20       4.23       2.63
# 4           4.34       4.35       2.75
# ...          ...        ...        ...
# 53935       5.75       5.76       3.50
# 53936       5.69       5.75       3.61
# 53937       5.66       5.68       3.56
# 53938       6.15       6.12       3.74
# 53939       5.83       5.87       3.64
#
# [53940 rows x 3 columns]

# %%
# Sort the 'cut' Series in ascending order (returns a Series) of df Dataframe
df.Diamond_Cut.sort_values(ascending =True)
# Out:
# 3850          Fair
# 51464         Fair
# 51466         Fair
# 10237         Fair
# 10760         Fair
#            ...
# 7402     Very Good
# 43101    Very Good
# 16893    Very Good
# 16898    Very Good
# 21164    Very Good
# Name: Diamond_Cut, Length: 53940, dtype: object

# %%
# Sort the 'cut' Series in descending order (returns a Series) of df Dataframe
df.Diamond_Cut.sort_values(ascending =False)
# Out:
# 8748     Very Good
# 23064    Very Good
# 23058    Very Good
# 31236    Very Good
# 19154    Very Good
#            ...
# 5595          Fair
# 5594          Fair
# 5585          Fair
# 5576          Fair
# 21921         Fair
# Name: Diamond_Cut, Length: 53940, dtype: object

# %%
# Sort the entire diamonds DataFrame by the 'carat' Series in ascending order.
df.sort_values("Diamond_Carat")
# Out:
#        Diamond_Carat Diamond_Cut  Diamond_X  Diamond_Y  Diamond_Z
# 31593           0.20     Premium       3.81       3.78       2.32
# 31597           0.20       Ideal       3.81       3.77       2.33
# 31596           0.20     Premium       3.73       3.71       2.33
# 31595           0.20       Ideal       3.86       3.84       2.30
# 31594           0.20     Premium       3.84       3.80       2.28
# ...              ...         ...        ...        ...        ...
# 25999           4.01     Premium      10.02       9.94       6.24
# 25998           4.01     Premium      10.14      10.10       6.17
# 27130           4.13        Fair      10.00       9.85       6.43
# 27630           4.50        Fair      10.23      10.16       6.72
# 27415           5.01        Fair      10.74      10.54       6.98
#
# [53940 rows x 5 columns]

# %%
# Sort the entire diamonds DataFrame by the 'carat' Series in descending order.
df.sort_values("Diamond_Carat", ascending = False)
# Out:
#        Diamond_Carat Diamond_Cut  Diamond_X  Diamond_Y  Diamond_Z
# 27415           5.01        Fair      10.74      10.54       6.98
# 27630           4.50        Fair      10.23      10.16       6.72
# 27130           4.13        Fair      10.00       9.85       6.43
# 25999           4.01     Premium      10.02       9.94       6.24
# 25998           4.01     Premium      10.14      10.10       6.17
# ...              ...         ...        ...        ...        ...
# 31592           0.20     Premium       3.81       3.78       2.24
# 31591           0.20     Premium       3.79       3.77       2.26
# 31601           0.20     Premium       3.77       3.72       2.31
# 14              0.20     Premium       3.79       3.75       2.27
# 31596           0.20     Premium       3.73       3.71       2.33
#
# [53940 rows x 5 columns]

# %%
# Filter the DataFrame rows to only show carat weight at least 0.3.

df.query("Diamond_Carat >= 0.3")
# Out:
#        Diamond_Carat Diamond_Cut  Diamond_X  Diamond_Y  Diamond_Z
# 4               0.31        Good       4.34       4.35       2.75
# 10              0.30        Good       4.25       4.28       2.73
# 13              0.31       Ideal       4.35       4.37       2.71
# 15              0.32     Premium       4.38       4.42       2.68
# 16              0.30       Ideal       4.31       4.34       2.68
# ...              ...         ...        ...        ...        ...
# 53935           0.72       Ideal       5.75       5.76       3.50
# 53936           0.72        Good       5.69       5.75       3.61
# 53937           0.70   Very Good       5.66       5.68       3.56
# 53938           0.86     Premium       6.15       6.12       3.74
# 53939           0.75       Ideal       5.83       5.87       3.64
#
# [52341 rows x 5 columns]

# %%
# Convert a python list to pandas series. 

test = [1,2,3,4,5]

pd.Series(test)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# Find the details of the diamonds where length>5, width>5 and depth>5

diamonds.query("x > 5 & y > 5 & z > 5 ")
# Out:
#        carat        cut color clarity  depth  table  price     x      y  \
# 11778   1.83       Fair     J      I1   70.0   58.0   5083  7.34   7.28
# 13002   2.14       Fair     J      I1   69.4   57.0   5405  7.74   7.70
# 13118   2.15       Fair     J      I1   65.5   57.0   5430  8.01   7.95
# 13562   1.96       Fair     F      I1   66.6   60.0   5554  7.59   7.56
# 13757   2.22       Fair     J      I1   66.7   56.0   5607  8.04   8.02
# ...      ...        ...   ...     ...    ...    ...    ...   ...    ...
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90   7.97
# 27749   2.29    Premium     I     VS2   60.8   60.0  18823  8.50   8.47
# 48410   0.51  Very Good     E     VS1   61.8   54.7   1970  5.12   5.15
# 49189   0.51      Ideal     E     VS1   61.8   55.0   2075  5.15  31.80
# 49905   0.50  Very Good     G    VVS1   63.7   58.0   2180  5.01   5.04
#
#            z quality - color
# 11778   5.12        Fair , J
# 13002   5.36        Fair , J
# ...

# %%
# Find the diamonds that are either Premium or Ideal

diamonds.query("cut == 'Premium' or cut == 'Ideal' ")
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z  \
# 0       0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 11      0.23    Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 12      0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53931   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53934   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53935   0.72    Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53938   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75    Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       quality - color
# 0           Ideal , E
# ...

# %%
# Find the diamonds that are with a Fair or Good or Premium
result = diamonds.query("cut == 'Fair' | cut == 'Good' | cut == 'Premium' ")

result.sort_values("cut", ascending=False)
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z  \
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 28711   0.23  Premium     E    VVS2   61.8   58.0    680  3.94  3.92  2.43
# 28713   0.23  Premium     E    VVS1   58.6   61.0    680  4.04  4.02  2.36
# 28714   0.23  Premium     E    VVS1   61.3   60.0    680  4.01  3.95  2.44
# 28715   0.23  Premium     E    VVS1   61.1   60.0    680  4.01  3.95  2.43
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 2366    1.50     Fair     H      I1   69.3   61.0   3175  6.99  6.81  4.78
# 38845   0.50     Fair     G     SI1   65.0   59.0   1050  4.99  4.97  3.24
# 38841   0.39     Fair     E     VS2   65.4   57.0   1049  4.61  4.54  2.99
# 4953    1.01     Fair     H     VS2   65.2   56.0   3733  6.23  6.19  4.05
# 6125    1.21     Fair     J     SI2   64.6   59.0   3984  6.74  6.64  4.32
#
#       quality - color
# 1         Premium , E
# ...

# %%
# Display all column labels of diamonds DataFrame
diamonds.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z', 'quality - color'],
#       dtype='object')

# %%
# Displayed as a list
list(diamonds.columns)
# Out:
# ['carat',
#  'cut',
#  'color',
#  'clarity',
#  'depth',
#  'table',
#  'price',
#  'x',
#  'y',
#  'z',
#  'quality - color']

# %%
# Read only a subset of 3 rows from diamonds DataFrame.
three_rows= pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv', nrows=3)
three_rows
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5     55    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8     61    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9     65    327  4.05  4.07  2.31

# %%
# Iterate through three_rows DataFrame.
for index, row in three_rows.iterrows():
    print(index, row.carat, row.cut, row.color, row.price)
# Out:
# 0 0.23 Ideal E 326
# 1 0.21 Premium E 326
# 2 0.23 Good E 327

# %%
# Drop all non-numeric columns from diamonds DataFrame

#Option 1
objects = ["cut", "color", "clarity", "quality - color"]
all_num = diamonds.drop(columns = objects)
all_num
# Out:
#        carat  depth  table  price     x     y     z
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75
# ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 7 columns]

# %%
# Include only numeric columns in the diamonds DataFrame.

import numpy as np
diamonds.select_dtypes(include=[np.number]).dtypes
# Out:
# carat    float64
# depth    float64
# table    float64
# price      int64
# x        float64
# y        float64
# z        float64
# dtype: object

# %%
all_num2 = diamonds[["carat","depth","table", "price", "x", "y", "z"]]
all_num2
# Out:
#        carat  depth  table  price     x     y     z
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75
# ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 7 columns]

# %%
# Calculate the mean of each numeric column of diamonds DataFrame
all_num.mean()
# Out:
# carat       0.797940
# depth      61.749405
# table      57.457184
# price    3932.799722
# x           5.731157
# y           5.734526
# z           3.538734
# dtype: float64

# %%
# Calculate the mean of each row of diamonds DataFrame
all_num.mean(axis=1)
# Out:
# 0         64.727143
# 1         65.292857
# 2         65.651429
# 3         66.535714
# 4         66.864286
#             ...
# 53935    412.932857
# 53936    412.981429
# 53937    413.628571
# 53938    413.267143
# 53939    412.898571
# Length: 53940, dtype: float64

# %%
# Calculate the mean of each row of diamonds DataFrame
diamonds.groupby('cut').price.mean()
# Out:
# cut
# Fair         4358.757764
# Good         3928.864452
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Name: price, dtype: float64

# %%
# Calculate count, minimum, maximum price for each cut of diamonds DataFrame.

diamonds.groupby('cut').price.count()
# Out:
# cut
# Fair          1610
# Good          4906
# Ideal        21551
# Premium      13791
# Very Good    12082
# Name: price, dtype: int64

# %%
# Calculate count, minimum, maximum price for each cut of diamonds DataFrame.

diamonds.groupby('cut').price.agg(['count','min','max'])
# Out:
#            count  min    max
# cut
# Fair        1610  337  18574
# Good        4906  327  18788
# Ideal      21551  326  18806
# Premium    13791  326  18823
# Very Good  12082  336  18818

# %%
diamonds.groupby('cut').price.max()
# Out:
# cut
# Fair         18574
# Good         18788
# Ideal        18806
# Premium      18823
# Very Good    18818
# Name: price, dtype: int64

# %%
# Create a side-by-side bar plot of the diamonds DataFrame.

diamonds.groupby('cut').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='cut'>

# %%
# Count how many times each value in cut series of diamonds DataFrame occurs
diamonds.cut.value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
#Display percentages of each value of cut series occurs in diamonds DataFrame. 

diamonds.cut.value_counts(normalize=True)
# Out:
# Ideal        0.399537
# Premium      0.255673
# Very Good    0.223990
# Good         0.090953
# Fair         0.029848
# Name: cut, dtype: float64

# %%
# Display the unique values in cut series of diamonds DataFrame.
diamonds.cut.unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
# Count the number of unique values in cut series of diamonds DataFrame.
diamonds.cut.nunique()
# Out:
# 5

# %%
# Calculate various summary statistics of cut series of diamonds DataFrame.
pd.crosstab(diamonds.cut, diamonds.price)
# Out:
# price      326    327    334    335    336    337    338    339    340    \
# cut
# Fair           0      0      0      0      0      1      0      0      0
# Good           0      1      0      1      0      0      0      1      0
# Ideal          1      0      0      0      0      0      0      0      1
# Premium        1      0      1      0      0      0      0      0      0
# Very Good      0      0      0      0      2      1      1      0      0
#
# price      342    ...  18787  18788  18791  18795  18797  18803  18804  18806  \
# cut               ...
# Fair           0  ...      0      0      0      0      0      0      0      0
# Good           0  ...      0      1      0      0      0      0      0      0
# Ideal          0  ...      1      0      1      0      0      0      1      1
# Premium        1  ...      0      0      1      2      1      0      0      0
# Very Good      0  ...      0      0      0      0      0      1      0      0
#
# price      18818  18823
# ...

# %% [markdown]
# Helpful video explaining pd.crosstab - https://www.youtube.com/watch?v=TIG3T-I7s04

# %%
# Calculate various summary statistics of cut series of diamonds DataFrame
diamonds.cut.describe()
# Out:
# count     53940
# unique        5
# top       Ideal
# freq      21551
# Name: cut, dtype: object

# %%
# Create a histogram of the 'carat' Series (distribution of a numerical variable) of diamonds DataFrame
diamonds.carat.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Create a bar plot of the 'value_counts' for the 'cut' series of diamonds DataFrame.

diamonds.cut.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Create a DataFrame of booleans (True if missing, False if not missing) from diamonds DataFrame
diamonds.isnull()
# Out:
#        carat    cut  color  clarity  depth  table  price      x      y      z  \
# 0      False  False  False    False  False  False  False  False  False  False
# 1      False  False  False    False  False  False  False  False  False  False
# 2      False  False  False    False  False  False  False  False  False  False
# 3      False  False  False    False  False  False  False  False  False  False
# 4      False  False  False    False  False  False  False  False  False  False
# ...      ...    ...    ...      ...    ...    ...    ...    ...    ...    ...
# 53935  False  False  False    False  False  False  False  False  False  False
# 53936  False  False  False    False  False  False  False  False  False  False
# 53937  False  False  False    False  False  False  False  False  False  False
# 53938  False  False  False    False  False  False  False  False  False  False
# 53939  False  False  False    False  False  False  False  False  False  False
#
#        quality - color
# ...

# %%
# Count the number of missing values in each Series of diamonds DataFrame.
diamonds.isnull().sum()
# Out:
# carat              0
# cut                0
# color              0
# clarity            0
# depth              0
# table              0
# price              0
# x                  0
# y                  0
# z                  0
# quality - color    0
# dtype: int64

# %%
# Check the number of rows and columns and drop those row if 'any' values are missing in a row of diamonds DataFrame. 
diamonds.shape
# Out:
# (53940, 11)

# %%
test= diamonds.dropna(how='any')
test.shape
# Out:
# (53940, 11)

# %%
# Set an existing column as the index of diamonds DataFrame.
test_df=diamonds.set_index('carat')
test_df
# Out:
#              cut color clarity  depth  table  price     x     y     z  \
# carat
# 0.23       Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 0.21     Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 0.23        Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 0.29     Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 0.31        Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...          ...   ...     ...    ...    ...    ...   ...   ...   ...
# 0.72       Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 0.72        Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 0.70   Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 0.86     Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 0.75       Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       quality - color
# carat
# 0.23        Ideal , E
# 0.21      Premium , E
# 0.23         Good , E
# ...

# %%
# Set an existing column as the index of diamonds DataFrame and restore the index name, and move the index back to a column.

diamonds.set_index('color', inplace=True)
diamonds.head(10)

#Restoring the index name
diamonds.index.name ='color'
diamonds.reset_index(inplace=True)
diamonds.head(10)
# Out:
#   color  carat        cut clarity  depth  table  price     x     y     z  \
# 0     E   0.23      Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     E   0.21    Premium     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     E   0.23       Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     I   0.29    Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     J   0.31       Good     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5     J   0.24  Very Good    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6     I   0.24  Very Good    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7     H   0.26  Very Good     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8     E   0.22       Fair     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9     H   0.23  Very Good     VS1   59.4   61.0    338  4.00  4.05  2.39
#
#   quality - color
# 0       Ideal , E
# 1     Premium , E
# 2        Good , E
# 3     Premium , I
# 4        Good , J
# 5   Very Good , J
# 6   Very Good , I
# ...

# %%
# Access a specified Series index and the Series values of diamonds DataFrame. 

#Example 1
diamonds.loc[0:5,'quality - color']
# Out:
# 0        Ideal , E
# 1      Premium , E
# 2         Good , E
# 3      Premium , I
# 4         Good , J
# 5    Very Good , J
# Name: quality - color, dtype: object

# %%
# Sort a Series by its values and index of diamonds DataFrame.
diamonds.cut.value_counts().sort_values()
# Out:
# Fair          1610
# Good          4906
# Very Good    12082
# Premium      13791
# Ideal        21551
# Name: cut, dtype: int64

# %%
diamonds.cut.value_counts().sort_index()
# Out:
# Fair          1610
# Good          4906
# Ideal        21551
# Premium      13791
# Very Good    12082
# Name: cut, dtype: int64

# %%
# Multiply of length, width and depth for each cut of diamonds DataFrame.
diamonds.x * diamonds.y * diamonds.z
# Out:
# 0         38.202030
# 1         34.505856
# 2         38.076885
# 3         46.724580
# 4         51.917250
#             ...
# 53935    115.920000
# 53936    118.110175
# 53937    114.449728
# 53938    140.766120
# 53939    124.568444
# Length: 53940, dtype: float64

# %%
# Concatenate the diamonds DataFrame with the 'color' Series.
pd.concat([diamonds, diamonds.color], axis=1)
# Out:
#       color  carat        cut clarity  depth  table  price     x     y     z  \
# 0         E   0.23      Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1         E   0.21    Premium     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2         E   0.23       Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3         I   0.29    Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4         J   0.31       Good     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...     ...    ...        ...     ...    ...    ...    ...   ...   ...   ...
# 53935     D   0.72      Ideal     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936     D   0.72       Good     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937     D   0.70  Very Good     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938     H   0.86    Premium     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939     D   0.75      Ideal     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       quality - color color
# ...

# %%
# Read specified rows and all columns of diamonds DataFrame
diamonds.loc[0, :]
# Out:
# color                      E
# carat                   0.23
# cut                    Ideal
# clarity                  SI2
# depth                   61.5
# table                   55.0
# price                    326
# x                       3.95
# y                       3.98
# z                       2.43
# quality - color    Ideal , E
# Name: 0, dtype: object

# %%
# Read rows 0, 5, 7 and all columns of diamonds DataFrame.
diamonds.loc[[0,5,7],:]
# Out:
#   color  carat        cut clarity  depth  table  price     x     y     z  \
# 0     E   0.23      Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# 5     J   0.24  Very Good    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 7     H   0.26  Very Good     SI1   61.9   55.0    337  4.07  4.11  2.53
#
#   quality - color
# 0       Ideal , E
# 5   Very Good , J
# 7   Very Good , H

# %%
# Read rows 2 through 5 and all columns of diamonds DataFrame. 
diamonds.loc[2:5,:]
# Out:
#   color  carat        cut clarity  depth  table  price     x     y     z  \
# 2     E   0.23       Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     I   0.29    Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     J   0.31       Good     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5     J   0.24  Very Good    VVS2   62.8   57.0    336  3.94  3.96  2.48
#
#   quality - color
# 2        Good , E
# 3     Premium , I
# 4        Good , J
# 5   Very Good , J

# %%
# Read rows 0 through 2 (inclusive), columns 'color' and 'price' of diamonds DataFrame. 

diamonds.loc[0:2,['color','price']]
# Out:
#   color  price
# 0     E    326
# 1     E    326
# 2     E    327

# %%
# Read rows 0 through 2 (inclusive), columns 'color' through 'price' (inclusive) of diamonds DataFrame
diamonds.loc[0:2,'color':'price']
# Out:
#   color  carat      cut clarity  depth  table  price
# 0     E   0.23    Ideal     SI2   61.5   55.0    326
# 1     E   0.21  Premium     SI1   59.8   61.0    326
# 2     E   0.23     Good     VS1   56.9   65.0    327

# %%
# Read rows in which the 'cut' is 'Premium', column 'color' of diamonds DataFrame.

diamonds.loc[diamonds.cut=='Premium','color']
# Out:
# 1        E
# 3        I
# 12       F
# 14       E
# 15       E
#         ..
# 53928    E
# 53930    E
# 53931    F
# 53934    D
# 53938    H
# Name: color, Length: 13791, dtype: object

# %%
# Read rows in positions 0 and 1, columns in positions 1 and 3 of diamonds DataFrame

diamonds.iloc[[0,1], [1,3]]
# Out:
#    carat clarity
# 0   0.23     SI2
# 1   0.21     SI1

# %%
# Read rows in positions 0 through 4, columns in positions 1 through 4 of diamonds DataFrame. 
diamonds.iloc[0:4, 1:4]
# Out:
#    carat      cut clarity
# 0   0.23    Ideal     SI2
# 1   0.21  Premium     SI1
# 2   0.23     Good     VS1
# 3   0.29  Premium     VS2

# %%
# Read rows in positions 0 through 4 (exclusive) and all columns of diamonds DataFrame. 
diamonds.iloc[0:5, :]
# Out:
#   color  carat      cut clarity  depth  table  price     x     y     z  \
# 0     E   0.23    Ideal     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1     E   0.21  Premium     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2     E   0.23     Good     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3     I   0.29  Premium     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4     J   0.31     Good     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#   quality - color
# 0       Ideal , E
# 1     Premium , E
# 2        Good , E
# 3     Premium , I
# 4        Good , J

# %%
# Read rows 2 through 5 (inclusive), columns in positions 0 through 2 (exclusive) of diamonds DataFrame.
diamonds.iloc[2:5, 0:2]
# Out:
#   color  carat
# 2     E   0.23
# 3     I   0.29
# 4     J   0.31

# %%
# Print a concise summary of diamonds DataFrame.
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   color            53940 non-null  object
#  1   carat            53940 non-null  float64
#  2   cut              53940 non-null  object
#  3   clarity          53940 non-null  object
#  4   depth            53940 non-null  float64
#  5   table            53940 non-null  float64
#  6   price            53940 non-null  int64
#  7   x                53940 non-null  float64
#  8   y                53940 non-null  float64
#  9   z                53940 non-null  float64
#  10  quality - color  53940 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 4.5+ MB

# %%
# Get the true memory usage by diamonds DataFrame. 
diamonds.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   color            53940 non-null  object
#  1   carat            53940 non-null  float64
#  2   cut              53940 non-null  object
#  3   clarity          53940 non-null  object
#  4   depth            53940 non-null  float64
#  5   table            53940 non-null  float64
#  6   price            53940 non-null  int64
#  7   x                53940 non-null  float64
#  8   y                53940 non-null  float64
#  9   z                53940 non-null  float64
#  10  quality - color  53940 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 15.7 MB

# %%
# Calculate the memory usage for each Series (in bytes) of diamonds DataFrame.
diamonds.memory_usage(deep=True)
# Out:
# Index                  128
# color              3128520
# carat               431520
# cut                3413674
# clarity            3242590
# depth               431520
# table               431520
# price               431520
# x                   431520
# y                   431520
# z                   431520
# quality - color    3629434
# dtype: int64

# %%
# Get randomly sample rows from diamonds DataFrame.
diamonds.sample(n=3)
# Out:
#       color  carat      cut clarity  depth  table  price     x     y     z  \
# 6073      I   1.09  Premium     SI1   61.6   61.0   3968  6.64  6.57  4.07
# 51803     D   0.70    Ideal     SI2   62.0   57.0   2415  5.68  5.65  3.51
# 3330      F   0.93     Good     SI2   61.3   62.0   3376  6.17  6.26  3.81
#
#       quality - color
# 6073      Premium , I
# 51803       Ideal , D
# 3330         Good , F

# %%
# Get sample 75% of the diamonds DataFrame's rows without replacement and store the remaining 25% of the rows in another DataFrame.
result = diamonds.sample(frac=0.75, random_state=99)
result
# Out:
#       color  carat        cut clarity  depth  table  price     x     y     z  \
# 42653     G   0.40    Premium      IF   60.8   58.0   1333  4.73  4.77  2.89
# 4069      D   0.31  Very Good     SI1   63.0   55.0    571  4.32  4.34  2.73
# 27580     F   1.60      Ideal     VS2   62.0   55.0  18421  7.49  7.54  4.66
# 33605     D   0.31       Good     SI2   63.1   54.0    462  4.33  4.38  2.75
# 34415     G   0.30      Ideal      IF   61.2   57.0    863  4.35  4.38  2.67
# ...     ...    ...        ...     ...    ...    ...    ...   ...   ...   ...
# 4677      F   1.05    Premium     SI2   61.1   59.0   3672  6.54  6.61  4.02
# 34855     G   0.30       Good    VVS2   63.8   56.0    878  4.29  4.27  2.73
# 13929     I   2.00       Fair      I1   66.0   60.0   5667  7.78  7.74  5.10
# 31091     G   0.33  Very Good    VVS2   62.8   57.0    752  4.39  4.47  2.78
# 41428     E   0.53  Very Good     SI2   63.2   54.0   1227  5.19  5.16  3.27
#
#       quality - color
# ...

# %%
others = diamonds.loc[~diamonds.index.isin(result.index), :]
others
# Out:
#       color  carat        cut clarity  depth  table  price     x     y     z  \
# 13        J   0.31      Ideal     SI2   62.2   54.0    344  4.35  4.37  2.71
# 14        E   0.20    Premium     SI2   60.2   62.0    345  3.79  3.75  2.27
# 18        J   0.30       Good     SI1   63.8   56.0    351  4.23  4.26  2.71
# 26        I   0.24    Premium     VS1   62.5   57.0    355  3.97  3.94  2.47
# 33        E   0.23  Very Good     VS1   59.5   58.0    402  4.01  4.06  2.40
# ...     ...    ...        ...     ...    ...    ...    ...   ...   ...   ...
# 53919     I   0.76      Ideal    VVS1   62.2   55.0   2753  5.89  5.87  3.66
# 53923     I   0.73      Ideal     VS2   61.3   56.0   2756  5.80  5.84  3.57
# 53926     E   0.71      Ideal     SI1   61.9   56.0   2756  5.71  5.73  3.54
# 53934     D   0.72    Premium     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53935     D   0.72      Ideal     SI1   60.8   57.0   2757  5.75  5.76  3.50
#
#       quality - color
# ...

# %%
# Read the diamonds DataFrame and detect duplicate color

diamonds.shape
# Out:
# (53940, 11)

# %%
diamonds.color.duplicated().sum()
# Out:
# 53933

# %%
diamonds.color.value_counts()
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %% [markdown]
# Out of 53,940 rows, there are 7 colors.
#
# 53,940 - 7 = 53,933 duplicated values

# %%
# count the duplicate rows of diamonds DataFrame.
diamonds.duplicated().sum()
# Out:
# 146
